# %% [markdown]
# # JupyterLab Demo

# %% [markdown]
# ### Fun features

# %% [markdown]
# #### Drag and drop cells

# %% [markdown]
# #### Notebook cell outputs can be pulled into new tab
# Right-click the cell and select "Create new view for output"

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,100,1000)
y = np.sin(x)

plt.plot(x,y)
plt.plot(x,2*y)
plt.show()
